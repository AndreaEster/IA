# %%
import pandas as pd
df = pd.read_json("Hechos.json")
df
# Out:
#    id  Catidad de estudiantes aprobaron Carrera con mas reprobaciones
# 0   1                                 8               Quimica y Civil
# 1   2                                 8               Quimica y Civil

# %%
import pandas as pd
df2 = pd.read_csv("MOCK_DATA.csv")
df2
# Out:
#     id    Nombre     Apellido         Carrera    Asignatura  Periodo_2021  \
# 0    1     Jorie  Nancekivell       Ing Civil     Filosofia             2
# 1    2     Brody       Malone  Ing Industrial      Calculo1             3
# 2    3  Riccardo     Maunsell    Ing Electica      Historia             2
# 3    4   Michail       Crumby     Ing Quimica  Programcion1             1
# 4    5     Ganny      Petrina    Ing Electica      Vectores             3
# 5    6    Cicely       Camoys       Ing Civil      Calculo2             2
# 6    7  Christal      Lequeux    Ing Electica     Filosofia             3
# 7    8   Sheeree       MacAne  Ing Industrial       Fisica1             3
# 8    9     Midge    Greenland       Ing Civil      Vectores             2
# 9   10    Saloma       Diboll       Ing Civil   Matematica1             2
# 10  11     Merci    Beckhouse     Ing Quimica      Historia             3
# 11  12     Olvan      Parrish    Ing Electica   Matematica1             2
# ...

# %%
pd.merge(df, df2, how='outer')
# Out:
#     id  Catidad de estudiantes aprobaron Carrera con mas reprobaciones  \
# 0    1                               8.0               Quimica y Civil
# 1    2                               8.0               Quimica y Civil
# 2    3                               NaN                           NaN
# 3    4                               NaN                           NaN
# 4    5                               NaN                           NaN
# 5    6                               NaN                           NaN
# 6    7                               NaN                           NaN
# 7    8                               NaN                           NaN
# 8    9                               NaN                           NaN
# 9   10                               NaN                           NaN
# 10  11                               NaN                           NaN
# 11  12                               NaN                           NaN
# ...

# %%
print ('Alumnos de Civil que reprobaron asignaturas en el 2021')
# Out:
# Alumnos de Civil que reprobaron asignaturas en el 2021

# %%
df3 = pd.merge(df, df2, how='outer')

# %%
df3
# Out:
#     id  Catidad de estudiantes aprobaron Carrera con mas reprobaciones  \
# 0    1                               8.0               Quimica y Civil
# 1    2                               8.0               Quimica y Civil
# 2    3                               NaN                           NaN
# 3    4                               NaN                           NaN
# 4    5                               NaN                           NaN
# 5    6                               NaN                           NaN
# 6    7                               NaN                           NaN
# 7    8                               NaN                           NaN
# 8    9                               NaN                           NaN
# 9   10                               NaN                           NaN
# 10  11                               NaN                           NaN
# 11  12                               NaN                           NaN
# ...

# %%
Dato= df ['id'] ==1
df
# Out:
#    id  Catidad de estudiantes aprobaron Carrera con mas reprobaciones
# 0   1                                 8               Quimica y Civil
# 1   2                                 8               Quimica y Civil

# %%
Dato= df ['Nombre'] == 'Cicely'
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Nombre'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
Dato= df3 ['id'] ==1
df3
# Out:
#     id  Catidad de estudiantes aprobaron Carrera con mas reprobaciones  \
# 0    1                               8.0               Quimica y Civil
# 1    2                               8.0               Quimica y Civil
# 2    3                               NaN                           NaN
# 3    4                               NaN                           NaN
# 4    5                               NaN                           NaN
# 5    6                               NaN                           NaN
# 6    7                               NaN                           NaN
# 7    8                               NaN                           NaN
# 8    9                               NaN                           NaN
# 9   10                               NaN                           NaN
# 10  11                               NaN                           NaN
# 11  12                               NaN                           NaN
# ...

# %%
Dato= df3 ['Nombre'] =='Cicely' and 'Midge'
print (Dato)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: Nombre, dtype: bool

# %%
Dato= df3 ['Nombre'] =='Cicely'
print (Dato)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: Nombre, dtype: bool

# %%
Dato= df3 ['Nombre'] =='Cicely'
print (Dato)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: Nombre, dtype: bool

# %%
Dato= df3 ['Nombre'] =='Cicely'
print (Dato)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: Nombre, dtype: bool

# %%
df3[0:1]
# Out:
#    id  Catidad de estudiantes aprobaron Carrera con mas reprobaciones Nombre  \
# 0   1                               8.0               Quimica y Civil  Jorie
#
#       Apellido    Carrera Asignatura  Periodo_2021 Aprobo
# 0  Nancekivell  Ing Civil  Filosofia             2     si

# %%
Dato= (df3 ['Nombre'] =='Cicely','Midge' )
print (Dato)
df3[Dato]
# Out:
# (0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: Nombre, dtype: bool, 'Midge')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:142, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(0     False
# 1     False
# 2     False
# 3     False
# ...

# %%
Dato= (df3 ['Nombre'] =='Cicely' )
print (Dato)
df3[Dato]
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: Nombre, dtype: bool
#    id  Catidad de estudiantes aprobaron Carrera con mas reprobaciones  Nombre  \
# 5   6                               NaN                           NaN  Cicely
#
#   Apellido    Carrera Asignatura  Periodo_2021 Aprobo
# 5   Camoys  Ing Civil   Calculo2             2     no

# %%
df3['Nombre']
# Out:
# 0        Jorie
# 1        Brody
# 2     Riccardo
# 3      Michail
# 4        Ganny
# 5       Cicely
# 6     Christal
# 7      Sheeree
# 8        Midge
# 9       Saloma
# 10       Merci
# 11       Olvan
# 12       Monti
# 13       Annie
# 14      Sawyer
# 15      Carlyn
# 16      Reidar
# 17     Sadella
# 18    Fiorenze
# 19       Locke
# Name: Nombre, dtype: object

# %%
df3 [['Asignatura']]
# Out:
#       Asignatura
# 0      Filosofia
# 1       Calculo1
# 2       Historia
# 3   Programcion1
# 4       Vectores
# 5       Calculo2
# 6      Filosofia
# 7        Fisica1
# 8       Vectores
# 9    Matematica1
# 10      Historia
# 11   Matematica1
# 12       Fisica1
# 13      Vectores
# 14       Fisica1
# 15      Calculo2
# 16    Ecuaciones
# 17     Filosofia
# 18      Calculo2
# 19     Filosofia
